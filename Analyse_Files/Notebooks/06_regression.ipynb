# %%
# ==========================================
# SETUP BLOCK - loads data, applies project helpers
# ==========================================

import os
import sys
import pandas as pd
import statsmodels.api as sm

sys.path.append(os.path.abspath(".."))

from Helper_functions import (
    clean_up_subjects,
    calculate_true_false_score,
    calculate_internet_terms_understanding_score,
    apply_dummy_spec,
)

from answer_categories import COLUMN_ALIASES
from lists import LIKERT_VALUE_MAPS

# regression-specific imports
from regression_config import (
    BASE_PREDICTORS,
    GENDER_DUMMIES_FEMALE_REF,
    GENDER_VARS_FEMALE_REF,
    PRIVACY_DUMMIES_NO_REF,
    PRIVACY_VARS_NO_REF,
)

LIKERT_COLS = [
    "Frequency of use education",
    "Frequency of use everyday life",
    "Understanding AI",
    "Deal with AI",
    "Use AI school and freetime",
    "Help of AI",
    "Reliability AI",
]

DATA_FILE = os.path.join("..", "Data", "Fertige Tabelle.xlsx")
df = pd.read_excel(DATA_FILE)
df.columns = df.columns.astype(str).str.strip()
df = df.rename(columns=COLUMN_ALIASES)

for col in ["Most used subjects", "Preferred Subjects", "Least preferred Subjects"]:
    if col in df.columns:
        df = clean_up_subjects(df, col)

true_false_cols = [f"True/False_{i}" for i in range(1, 7)]
if all(c in df.columns for c in true_false_cols):
    df = calculate_true_false_score(df)

if any(c.startswith("Internet terms_") for c in df.columns):
    df = calculate_internet_terms_understanding_score(df)


df = apply_dummy_spec(df, GENDER_DUMMIES_FEMALE_REF)
df = apply_dummy_spec(df, PRIVACY_DUMMIES_NO_REF)


REGRESSION_PREDICTORS = (
    BASE_PREDICTORS
    + GENDER_VARS_FEMALE_REF
    + PRIVACY_VARS_NO_REF
)

# ==========================================
# Convert Likert variables to numeric
# ==========================================

for col, mapping in LIKERT_VALUE_MAPS.items():
    if col in df.columns:
        df[col] = (
            df[col]
            .astype("string")
            .str.strip()
            .map(mapping)
        )

#delete unspecified genders
df = df[df["Gender"] != "Keine Angabe"].copy()

print("Setup complete – DataFrame loaded and preprocessed")
print(f"Rows: {len(df)}, Columns: {len(df.columns)}")
print("Regression predictors:")
print(REGRESSION_PREDICTORS)

# %%
# ==========================================
# REGRESSION HELPER
# ==========================================



def run_regression(df_in: pd.DataFrame, dependent_var: str, predictors: list[str], model_name: str):
    missing = [c for c in [dependent_var] + predictors if c not in df_in.columns]
    if missing:
        raise ValueError(f"Missing columns for {model_name}: {missing}")

    data = df_in[[dependent_var] + predictors].copy()

    # numeric coercion
    for c in [dependent_var] + predictors:
        data[c] = pd.to_numeric(data[c], errors="coerce")

    # listwise deletion for the selected model
    data = data.dropna()

    dummy_cols = [c for c in data.columns if c.startswith("gender_") or c.startswith("privacy_")]
    if dummy_cols:
        data[dummy_cols] = data[dummy_cols].astype(int)

    X = sm.add_constant(data[predictors], has_constant="add")
    y = data[dependent_var]

    model = sm.OLS(y, X).fit()

    print(f"\n=== {model_name} ===")
    print(f"N = {len(data)}")
    print(model.summary())

    return model


# ==========================================
# DATA SPLITS
# ==========================================

# all students
df_all = df.copy()

# users only
df_users = df[df["Use AI school and freetime"] != "Nie"].copy()

# %%
# ==========================================
# MODEL 1: ALL STUDENTS
# DV = overall AI usage
# only predictors available for almost everyone
# ==========================================

DEPENDENT_VAR_ALL = "Use AI school and freetime"

PREDICTORS_ALL = [
    "Age",
    "CRT_points",
    "Internet_Understanding_Score",
    "True_False_Score",
    "gender_Männlich",
    "privacy_Ja",
    "privacy_Ich habe darüber noch nie nachgedacht."
]

model_all_students = run_regression(
    df_all,
    DEPENDENT_VAR_ALL,
    PREDICTORS_ALL,
    model_name="Model 1: All students predicting overall AI usage"
)


# ==========================================
# MODEL 2: USERS ONLY
# DV = overall AI usage
# demographics + skills + attitudes
# ==========================================

DEPENDENT_VAR_USAGE = "Use AI school and freetime"

PREDICTORS_USAGE = [
    "Age",
    "CRT_points",
    "Internet_Understanding_Score",
    "Help of AI",
    "Deal with AI",
    "Understanding AI",
    "True_False_Score",
    "Reliability AI",
    "gender_Männlich",
    "privacy_Ja",
    "privacy_Ich habe darüber noch nie nachgedacht."
]

model_usage_users = run_regression(
    df_users,
    DEPENDENT_VAR_USAGE,
    PREDICTORS_USAGE,
    model_name="Model 2: Users only predicting overall AI usage"
)


# ==========================================
# MODEL 3: USERS ONLY
# DV = Helpfulness of AI
# ==========================================

DEPENDENT_VAR_HELP = "Help of AI"

PREDICTORS_HELP = [
    "Use AI school and freetime",
    "Age",
    "CRT_points",
    "Internet_Understanding_Score",
    "Deal with AI",
    "Understanding AI",
    "True_False_Score",
    "Reliability AI",
    "gender_Männlich",
    "privacy_Ja",
    "privacy_Ich habe darüber noch nie nachgedacht."
]

model_help = run_regression(
    df_users,
    DEPENDENT_VAR_HELP,
    PREDICTORS_HELP,
    model_name="Model 3: Users only predicting helpfulness of AI"
)


# ==========================================
# MODEL 4: USERS ONLY
# DV = Perceived reliability of AI
# ==========================================

DEPENDENT_VAR_RELIABILITY = "Reliability AI"

PREDICTORS_RELIABILITY = [
    "Use AI school and freetime",
    "Age",
    "CRT_points",
    "Internet_Understanding_Score",
    "Deal with AI",
    "Understanding AI",
    "True_False_Score",
    "Help of AI",
    "gender_Männlich",
    "privacy_Ja",
    "privacy_Ich habe darüber noch nie nachgedacht."
]

model_reliability = run_regression(
    df_users,
    DEPENDENT_VAR_RELIABILITY,
    PREDICTORS_RELIABILITY,
    model_name="Model 4: Users only predicting perceived reliability of AI"
)


# ==========================================
# MODEL 5: USERS ONLY (OPTIONAL)
# DV = attitudes toward teachers using AI for grading
# ==========================================

DEPENDENT_VAR_GRADING = "Teachers giving grades"

PREDICTORS_GRADING = [
    "Use AI school and freetime",
    "Age",
    "CRT_points",
    "Internet_Understanding_Score",
    "Deal with AI",
    "Understanding AI",
    "True_False_Score",
    "Reliability AI",
    "Help of AI",
    "gender_Männlich",
    "privacy_Ja",
    "privacy_Ich habe darüber noch nie nachgedacht."
]

model_teacher_grading = run_regression(
    df_users,
    DEPENDENT_VAR_GRADING,
    PREDICTORS_GRADING,
    model_name="Model 5: Users only predicting acceptance of teachers using AI for grading"
)
